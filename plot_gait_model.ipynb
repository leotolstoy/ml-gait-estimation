# %%
""" Notebook that plots the gait model"""
import numpy as np
from time import strftime
np.set_printoptions(precision=4)
import time
import gc

import matplotlib
import matplotlib.pyplot as plt
import torch

gc.disable()

import plot_gait_model


plot_gait_model.main()
# Out:
# /home/jupyter/ml-gait-estimation
# Using GPU.
# Lowest Loss: 0.035824309887171175
