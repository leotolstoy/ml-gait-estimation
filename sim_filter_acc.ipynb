# %%
""" Simulates the gait transformer estimator using loaded data. """
import numpy as np
from time import strftime
np.set_printoptions(precision=4)
import time
import gc

import matplotlib
import matplotlib.pyplot as plt
import torch



gc.disable()

import sim_filter_acc


sim_filter_acc.main()
# Out:
# /home/jupyter/ml-gait-estimation
# 5519
# Ran simulation loop in 0.0995 seconds
# Sampling Rate
# 100.00072490558107
# this is done (show state)
