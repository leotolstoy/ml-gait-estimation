# %%
### """ Simulates the gait transformer estimator using loaded data. """
import sim_gait_transformer


sim_gait_transformer.main()
# Out:
# /home/jupyter/ml-gait-estimation
# 2916
# Using GPU.
# Total Trainable Params: 319141
# ./full_models/apollyon-three-stairs/finetune_AB05_exoboot/
# Lowest Loss General: 0.12969229495725954
# Lowest Loss: 0.010548620141964282
# Total Trainable Params: 17414
# Lowest Loss: 0.09318956837678097
# Total Trainable Params: 9877
# ignoring synch count
# Ran simulation loop in 60.6482 seconds
# Sampling Rate
# -87.13851903482025
# Phase Losses: 0.030
# Speed Losses: 0.106
# Incline Losses: 2.291
# Is Stairs Accuracy: 0.915
# Is Stairs Accuracy, Ascent: nan
# Is Stairs Accuracy, Descent: nan
# this is done (show state)
# /home/jupyter/ml-gait-estimation/training_utils.py:440: RuntimeWarning: invalid value encountered in long_scalars
#   stair_height_accuracy_ascent = np.sum(true_labels[true_labels[:,3] == 1,3] == predictions[true_labels[:,3] == 1,3])/len(true_labels[true_labels[:,3] == 1,3])
# /home/jupyter/ml-gait-estimation/training_utils.py:441: RuntimeWarning: invalid value encountered in long_scalars
#   stair_height_accuracy_descent = np.sum(true_labels[true_labels[:,3] == -1,3] == predictions[true_labels[:,3] == -1,3])/len(true_labels[true_labels[:,3] == -1,3])
