# %%
### """ Simulates the gait transformer estimator using loaded data. """
import sim_gait_transformer


sim_gait_transformer.main()
# Out:
# /home/jupyter/ml-gait-estimation
# 3698
# Using GPU.
# Total Trainable Params: 319141
# ./full_models/apollyon-three-stairs/finetune_AB04_exoboot/
# Lowest Loss General: 0.12287193173184417
# Lowest Loss: 0.010548620141964282
# Total Trainable Params: 17414
# Lowest Loss: 0.09318956837678097
# Total Trainable Params: 9877
# Total Trainable Params: 111953
# ./full_models/stairs-predictor/model_save_xval/
# Lowest Loss General: 0.018808772702282785
# Ran simulation loop in 56.1873 seconds
# Sampling Rate
# -1960.9810824876922
# Phase Losses: 0.059
# Speed Losses: 0.123
# Incline Losses: 2.299
# Is Stairs Accuracy: 0.946
# Is Stairs Accuracy, Ascent: 1.000
# Is Stairs Accuracy, Descent: nan
# this is done (show state)
# /home/jupyter/ml-gait-estimation/training_utils.py:333: RuntimeWarning: invalid value encountered in long_scalars
#   stair_height_accuracy_descent = np.sum(true_labels[true_labels[:,3] == -1,3] == predictions[true_labels[:,3] == -1,3])/len(true_labels[true_labels[:,3] == -1,3])
